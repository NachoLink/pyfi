# %%
import pandas as pd

df = pd.read_csv("2016.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  ReportDate    API_WELLNO  \
# 0           0         14709              51  2016-01-01  3.306101e+13
# 1           1         14859             201  2016-01-01  3.306101e+13
# 2           2         14876             218  2016-01-01  3.306101e+13
# 3           3         14941             283  2016-01-01  3.306102e+13
# 4           4         14947             289  2016-01-01  3.306102e+13
#
#     FileNo               Company            WellName Quarter  Section  ...  \
# 0  17795.0   EOG RESOURCES, INC.         ROSS  3-04H    LOT3      4.0  ...
# 1  16893.0  STATOIL OIL & GAS LP       BAKKE 23  1-H    NWNW     23.0  ...
# 2  19058.0  STATOIL OIL & GAS LP  BURES 20-29  #1TFH    NWNE     20.0  ...
# 3  22461.0  STATOIL OIL & GAS LP  LIFFRIG  29-20 #4H    SWSW     29.0  ...
# 4  22007.0  STATOIL OIL & GAS LP  PANZER  22-23 #1-H    SWSW     22.0  ...
#
#       Wtr  Days    Runs     Gas GasSold  Flared        Lat        Long  \
# ...
