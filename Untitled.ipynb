# %%
import pandas as pd

df = pd.read_csv("/Users/jnesnky/Desktop/untitled folder/Bakken/combinedfile.csv")

# %%
d = df[df['County']=='MCK']

# %%
d.shape
# Out:
# (217470, 21)

# %%
df.shape

# %%
d.to_csv('/Users/jnesnky/Desktop/untitled folder/Bakken/MCK.csv')

# %%
d = df.copy()
d.index("ReportDate", inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-ebf35b0eae9d> in <module>
#       1 d = df.copy()
# ----> 2 d.index("ReportDate", inplace = True)
#
# TypeError: 'RangeIndex' object is not callable

# %%
df_pivot = pd.pivot_table(df, index=df.index.month, columns=df.index.year, values='Data')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# create fake time series dataframe
index = pd.date_range(start='01-Jan-2012', end='01-01-2019', freq='M')
data = np.random.randn(len(index))
df = pd.DataFrame(data, index, columns=['Data'])

# pivot to get by month in rows, then year in columns
df_pivot = pd.pivot_table(df, index=df.index.month, columns=df.index.year, values='Data')

# plot
ax = df_pivot.plot(title='Data by Year', figsize=(6,4))
ax.get_lines()[-1].set_linewidth(5)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

ax.figure.tight_layout()
plt.show()

# %%
df_pivot.head()
# Out:
#        2012      2013      2014      2015      2016      2017      2018
# 1  0.536879 -0.172084  2.036036  0.177680 -1.868604  0.996987 -1.347203
# 2 -0.365300  0.209613  1.433412 -0.246148 -1.340145 -1.582831  1.304300
# 3  0.151764  1.001415  0.959928  0.521814  1.636511  1.536900 -0.557592
# 4 -2.286618  0.251409  0.347452  0.954807 -1.301820 -0.968586 -0.365550
# 5 -1.342323 -0.171916  0.737196  0.187319 -1.294023 -0.475832 -0.715788

# %%
d_pivot = pd.pivot_table(d, index=d['ReportDate'], columns=d['WellName'], values=d['Oil'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-f9a61f9f7b62> in <module>
# ----> 1 d_pivot = pd.pivot_table(d, index=d['ReportDate'], columns=d['WellName'], values=d['Oil'])
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      70         for i in values:
#      71             if i not in data:
# ---> 72                 raise KeyError(i)
#      73
#      74         to_filter = []
#
# KeyError: 2339.0

# %%
d.head()
# Out:
#   ReportDate    API_WELLNO  FileNo                      Company  \
# 0     8/1/17  3.305300e+13   23615  MUREX PETROLEUM CORPORATION
# 1     8/1/17  3.305300e+13   22021         STATOIL OIL & GAS LP
# 2     8/1/17  3.305300e+13   25091         STATOIL OIL & GAS LP
# 3     8/1/17  3.305310e+13   25645         STATOIL OIL & GAS LP
# 4     8/1/17  3.305300e+13   25092         STATOIL OIL & GAS LP
#
#                   WellName Quarter  Section  Township  Range County  ...  \
# 0  AMBER ELIZABETH  36-25H    SESW       36       151    101    MCK  ...
# 1         BILL  14-23 2TFH    SWSW       11       151    101    MCK  ...
# 2           BILL  14-23 3H    NWNE       14       151    101    MCK  ...
# 3         BILL  14-23 4TFH    NWNE       14       151    101    MCK  ...
# 4         BILL  14-23 5TFH    NWNE       14       151    101    MCK  ...
#
#      Pool     Oil     Wtr  Days  Runs     Gas  GasSold  Flared        Lat  \
# 0  BAKKEN  2339.0  2412.0  31.0  2222  3624.0     3139    95.0  47.849140
# 1  BAKKEN  1471.0  2758.0  31.0  1513  1615.0     1447   137.0  47.907426
# 2  BAKKEN  3291.0  5568.0  31.0  3234  2774.0     2692    51.0  47.904553
# 3  BAKKEN     0.0     0.0  31.0     0     0.0        0     0.0  47.904553
# 4  BAKKEN     0.0     0.0  31.0     0     0.0        0     0.0  47.904553
#
#          Long
# 0 -103.553342
# 1 -103.579904
# 2 -103.569154
# 3 -103.569032
# 4 -103.569276
#
# [5 rows x 21 columns]
