# %%
import pandas as pd

df = pd.read_csv('shell financial data.csv')

# %%
rename = {'Unnamed: 0': 'Date'}
df.rename(rename, axis=1, inplace=True)

# %%
df.to_csv('shell financial data.csv', index=False)

# %%
df.set_index("Date", inplace=True)

# %%
df.tail()
# Out:
#             Revenue  Cost Of Goods Sold  Gross Profit  \
# Date
# 2006-03-31  75964.0             62203.0       13761.0
# 2005-12-31  75496.0             64391.0       11105.0
# 2005-09-30  76435.0             60979.0       15456.0
# 2005-06-30  82644.0             69712.0       12932.0
# 2005-03-31  72156.0             58826.0       13330.0
#
#             Research And Development Expenses  SG&A Expenses  \
# Date
# 2006-03-31                                NaN         3413.0
# 2005-12-31                                NaN         4263.0
# 2005-09-30                                NaN         3763.0
# 2005-06-30                                NaN         3917.0
# 2005-03-31                                NaN         3539.0
#
#             Other Operating Income Or Expenses  Operating Expenses  \
# Date
# 2006-03-31                                 NaN             65616.0
# 2005-12-31                                 NaN             68654.0
# ...

# %%
from quandl_config import QUANDL_API_KEY # file with my personal Quandl Key
import quandl

symbols = {
        "Brent": "FRED/DCOILBRENTEU",
        "Henry_Hub": "CHRIS/CME_NG1"
        }
for k, v in symbols.items():
    k = quandl.get(v, start = '2005-03-31',  api_key = QUANDL_API_KEY, collapse = 'quarterly')

# %%
Henry_Hub = quandl.get(symbols['Henry_Hub'], start = '2005-03-31',  api_key = QUANDL_API_KEY, collapse = 'quarterly')

# %%
df_merged = pd.merge(df, crude, left_index = True, right_index= True)

# %%
df.head()
# Out:
#              Revenue  Cost Of Goods Sold  Gross Profit  \
# Date
# 2019-09-30   89541.0             70546.0       18995.0
# 2019-06-30   91838.0             75864.0       15974.0
# 2019-03-31   85662.0             66583.0       19079.0
# 2018-12-31  104626.0             86028.0       18598.0
# 2018-09-30  101548.0             82648.0       18900.0
#
#             Research And Development Expenses  SG&A Expenses  \
# Date
# 2019-09-30                              219.0         2429.0
# 2019-06-30                              225.0         2881.0
# 2019-03-31                              212.0         2352.0
# 2018-12-31                              314.0         3162.0
# 2018-09-30                              227.0         2829.0
#
#             Other Operating Income Or Expenses  Operating Expenses  \
# Date
# 2019-09-30                                 NaN             80009.0
# 2019-06-30                                 NaN             85669.0
# ...

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = df_merged.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df_merged[['Revenue', 'Value']].corr()
# Out:
#           Revenue     Value
# Revenue  1.000000  0.900632
# Value    0.900632  1.000000

# %%
import statsmodels.api as sm
Y = df1['Revenue']
X = df1[['Value', 'Settle']]
X = sm.add_constant(X)
model = sm.OLS(Y,X)
results = model.fit()
results.params
# Out:
# const     35112.654170
# Value       773.524749
# Settle     -439.453011
# dtype: float64

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Revenue   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.807
# Method:                 Least Squares   F-statistic:                     122.5
# Date:                Thu, 12 Mar 2020   Prob (F-statistic):           3.57e-21
# Time:                        15:05:45   Log-Likelihood:                -621.99
# No. Observations:                  59   AIC:                             1250.
# Df Residuals:                      56   BIC:                             1256.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.511e+04   4295.116      8.175      0.000    2.65e+04    4.37e+04
# ...

# %%
Brent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-c383fae7e103> in <module>
# ----> 1 Brent
#
# NameError: name 'Brent' is not defined

# %%
df1 = df_merged.merge(Henry_Hub, left_index=True, right_index = True)

# %%
df1.head()
# Out:
#             Revenue  Cost Of Goods Sold  Gross Profit  \
# Date
# 2005-03-31  72156.0             58826.0       13330.0
# 2005-06-30  82644.0             69712.0       12932.0
# 2005-09-30  76435.0             60979.0       15456.0
# 2005-12-31  75496.0             64391.0       11105.0
# 2006-03-31  75964.0             62203.0       13761.0
#
#             Research And Development Expenses  SG&A Expenses  \
# Date
# 2005-03-31                                NaN         3539.0
# 2005-06-30                                NaN         3917.0
# 2005-09-30                                NaN         3763.0
# 2005-12-31                                NaN         4263.0
# 2006-03-31                                NaN         3413.0
#
#             Other Operating Income Or Expenses  Operating Expenses  \
# Date
# 2005-03-31                                 NaN             62365.0
# 2005-06-30                                 NaN             73629.0
# ...
